# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import library
import math

# %%
data = library.loadList('exoplanet.csv')
col = {'mass':2,'rad':3,'method':13}

# %%
#Method counting function shortcut
def getMethod(method):
    if method == 'transit':
        transitLen += 1
    elif method == 'RV':
        rvLen += 1
    elif method == 'microlensing':
        microLen += 1
    elif method == 'imaging':
        imagingLen += 1
    else:
        timingLen += 1

#Lists
methodList = []
massList = []
radList = []

#counters
transitLen = 0
rvLen = 0
microLen = 0
imagingLen = 0
timingLen = 0

#mainLoop
for n in range(len(data)):
    method = data[n][col['method']]
    mass = data[n][col['mass']]
    radius = data[n][col['rad']]
    if method != '':
        getMethod(method)
    if method != '' and radius != '':
        radius = float(radius)
        radius /= earthRadius
        radList += [[round(radius,2),method]]

#Print the basic breakdown:
methodList += [transitLen,rvLen,microLen,imagingLen,timingLen]
print('Amount of exoplanet discoveries per method:')
print('[transit, radial velocity, microlensing, imaging, timing]')
print(methodList)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/1z/9_8zm1jd2h7dyhpwxvmwwt800000gp/T/ipykernel_18350/2417867043.py in <module>
#      30     radius = data[n][col['rad']]
#      31     if method != '':
# ---> 32         getMethod(method)
#      33         methodList += [transitLen,rvLen,microLen,imagingLen,timingLen]
#      34     if method != '' and mass != '':
#
# /var/folders/1z/9_8zm1jd2h7dyhpwxvmwwt800000gp/T/ipykernel_18350/2417867043.py in getMethod(method)
#       2 def getMethod(method):
#       3     if method == 'transit':
# ----> 4         transitLen += 1
#       5     elif method == 'RV':
#       6         rvLen += 1
#
# UnboundLocalError: local variable 'transitLen' referenced before assignment

# %%
for n in range(len(data)):
    method = data[n][col['method']]
    mass = data[n][col['mass']]
    if method != '' and mass != '':
        mass = float(mass)
        mass /= earthMass
        if mass <= 200:
            getMethod(method)
            lowList.append(round(mass,2))
        elif mass > 200 and mass <= 400:
            medList.append(round(mass,2))
        else:
            largeList.append(round(mass,2))

# %%
massList = []

#Defining constants:
earthMass = 0.003
earthRadius = 0.08928571428

#Processing the mass (graph #2): 
smallList = []
medList = []
largeList = []
for n in range(len(data)):
    mass = data[n][col['mass']]
    method = data[n][col['method']]
    if mass != '' and method != '':
        mass = float(mass)
        mass /= earthMass
        if mass <= 200:
            lowList.append(round(mass,2))
        elif mass > 200 and mass <= 400:
            medList.append(round(mass,2))
        else:
            largeList.append(round(mass,2))
# Out:
# [203.33, 205.0, 206.0, 206.67, 206.67, 206.67, 206.67, 206.67, 207.33, 208.67, 210.0, 210.0, 212.0, 213.33, 213.33, 215.0, 216.67, 217.33, 219.3, 220.0, 220.0, 220.0, 223.33, 223.33, 223.33, 224.0, 225.0, 226.33, 226.67, 226.67, 226.67, 226.67, 228.33, 229.64, 230.0, 232.0, 233.33, 233.33, 233.33, 236.67, 237.0, 238.0, 240.0, 240.0, 242.33, 243.33, 243.33, 244.33, 246.67, 250.0, 250.0, 253.33, 253.33, 253.67, 254.33, 256.67, 256.67, 259.33, 260.0, 260.0, 263.33, 263.33, 266.67, 266.67, 270.0, 272.67, 273.33, 273.33, 273.33, 276.67, 276.87, 279.0, 280.0, 280.0, 280.0, 280.97, 283.33, 283.33, 283.33, 283.33, 284.67, 285.0, 286.67, 286.67, 287.67, 288.33, 289.0, 289.67, 293.33, 294.67, 296.67, 297.33, 297.33, 298.33, 300.0, 300.0, 300.0, 300.0, 300.67, 302.33, 303.33, 303.33, 303.33, 303.67, 304.67, 305.67, 305.67, 306.67, 306.67, 306.67, 310.0, 313.0, 313.33, 313.33, 313.33, 313.67, 314.67, 315.67, 316.67, 316.67, 316.67, 316.67, 320.0, 320.0, 320.0, 320.0, 325.0, 326.67, 330.0, 333.33
# ...

# %%
#Print the mass data that will be used (second visualization):
massList.sort()
print('Mass List for Mass to Method used:')
print(massList)
length = len(massList)
print('There are ' + str(length) + ' elements in this list.')
# Out:
# Mass List for Mass to Method used:
# ...

# %%
radList.sort()
print('Radius list for Radius and Method used:')
print(radList)
length = len(radList)
print('There are ' + str(length) + ' elements in this list.')
# Out:
# Radius list for Radius and Method used:
# ...

# %%
df = pd.DataFrame(methodList,index=['transit','RV', 'microlensing', 'imaging', 'timing'],
                  columns=['Amount'])
df.index.name = 'Method'
df = df.style.set_caption("Amount of Planets Detected per Detection Method")
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_f64ae_">
#   <caption>Amount of Planets Detected per Detection Method</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Method</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f64ae_level0_row0" class="row_heading level0 row0" >transit</th>
#       <td id="T_f64ae_row0_col0" class="data row0 col0" >2643</td>
#     </tr>
#     <tr>
#       <th id="T_f64ae_level0_row1" class="row_heading level0 row1" >RV</th>
#       <td id="T_f64ae_row1_col0" class="data row1 col0" >659</td>
#     </tr>
#     <tr>
#       <th id="T_f64ae_level0_row2" class="row_heading level0 row2" >microlensing</th>
#       <td id="T_f64ae_row2_col0" class="data row2 col0" >40</td>
#     </tr>
#     <tr>
# ...

# %%
df1 = pd.DataFrame(lowList,index=['transit','RV', 'microlensing', 'imaging', 'timing'],
                  columns=['Amount'])

df2 = pd.DataFrame(medList,index=['transit','RV', 'microlensing', 'imaging', 'timing'],
                  columns=['Amount'])

df3 = pd.DataFrame(highList,index=['transit','RV', 'microlensing', 'imaging', 'timing'],
                  columns=['Amount'])

df4 = pd.DataFrame(extremeList,index=['transit','RV', 'microlensing', 'imaging', 'timing'],
                  columns=['Amount'])

df1
df2
df3

# %%
plt.figure(figsize=(15,5))

plt.subplot(211)
labelsList = ['transit', 'RV', 'microlensing', 'imaging', 'timing']
amount = masterList
labels = labelsList
plt.barh(labels,amount,color='orange')
legendLabels = ['0-2','2-4','4-6','6+']
legend = plt.legend(legendLabels,loc=1)
legend.set_title('Mass (Jpt.)')

plt.subplot(212)

plt.suptitle('Amount of Exoplanets Detected for each Method',fontweight='bold',fontsize=15)
plt.show()
